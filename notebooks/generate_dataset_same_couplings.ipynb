# %% [markdown]
# ## Dataset generation from deformable mirror
#
# A Parabolic GRIN fiber or a Step-Index fiber can be used
#
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from mmfsim.grid import Grid
from mmfsim.fiber import GrinFiber, StepIndexFiber
from mmfsim.datasets import SimulatedStepIndexSpeckleOutputDataset

from IPython.display import clear_output
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Setup
#
# Set the computation grid and the fiber characteristics

# %%
fiber_type: str = 'step' # 'grin' or 'step'
grid_settings: dict = {'pixel_size': 0.5e-6, 'pixel_numbers': (128, 128)}
fiber_settings: dict = {'radius': 25e-6, 'wavelength': 1064e-9, 'n1': 1.465, 'n2': 1.44839}
fourier_settings: dict = {'pad': 1}
export_settings: dict = {'return_output_fields': False, 'add_exp_noise': True, 'noise_func': np.median, 'file_type': 'hdf5', 'max_fields_per_file': 10000}

dataset_lengths: list[int] = [5000, 5000, 10000, 20000, 30000, 30000, 40000]
dataset_actuators: list[int] = [4, 8, 12, 16, 20, 24, 32]

# %% [markdown]
# ### Dataset generation
#
# Generate the grid and the fiber

# %%
grid = Grid(**grid_settings)

if fiber_type.lower() in ['grin']:
    fiber = GrinFiber(**fiber_settings)
elif fiber_type.lower() in ['step', 'si']:
    fiber = StepIndexFiber(**fiber_settings)
else:
    raise ValueError(f"Unknown fiber type.")
print(fiber)
# Out:
# c:\users\saucourt\coding\mmf_lp_modes\mmfsim\fiber.py:248: RuntimeWarning: invalid value encountered in divide
#   return sp.jv(n, u) / (u * sp.jv(n - 1, u)) + sp.kn(n, w) / (w * sp.kn(n - 1, w))
# c:\users\saucourt\coding\mmf_lp_modes\mmfsim\fiber.py:247: RuntimeWarning: invalid value encountered in sqrt
#   w = np.sqrt(v**2 - u**2)
# StepIndexFiber instance with:
#   - Radius: 25.0 um
#   - Core index: 1.465
#   - Cladding index: 1.44839
#   - Wavelength: 1064.0 nm
#   - Numerical aperture: 0.220
#   - Number of guided LP modes: 140
#   - Number of guided LP modes (counting degenerates): 269
#   - First 10 LP_n,m modes characteristics:
#   n_eff      h          n          m
# [[ 1.46491477  0.          0.          1.        ]
#  [ 1.46478363  2.          1.          1.        ]
#  [ 1.46461132  4.          2.          1.        ]
#  [ 1.46455097  1.          0.          2.        ]
#  [ 1.46440012  6.          3.          1.        ]
#  [ 1.46427477  3.          1.          2.        ]
#  [ 1.46415143  8.          4.          1.        ]
#  [ 1.46395609  5.          2.          2.        ]
#  [ 1.46389667  2.          0.          3.        ]
#  [ 1.46386618 10.          5.          1.        ]]

# %% [markdown]
# Compute and store the modes for a much faster dataset generation, plot one for checking extent

# %%
fiber.compute_modes_fields(grid)
plt.imshow(fiber._modes[:,:,1,-1])

# %%
common_coupling_matrix = fiber.modes_coupling_matrix(complex=complex, full=True, degen=True)

for i in range(len(dataset_lengths)):
    # Gather the dataset length for the indexed number of macro-actuators
    dataset_settings: dict = {'length': dataset_lengths[i], 'degen': True, 'phases_dim': (dataset_actuators[i], dataset_actuators[i])}
    
    # Create/Overwrite a dataset instance
    dset = SimulatedStepIndexSpeckleOutputDataset(fiber, grid, N_modes=fiber._N_modes_degen, length=dataset_settings['length'])
    
    # Overwrite the random coupling matrix with the computed one
    dset._coupling_matrix = np.copy(common_coupling_matrix)
    
    # Compute the near fields from the transfer matrix
    dset.compute_from_transfer_matrix(phases_dim=dataset_settings['phases_dim'])
    
    # Compute the far fields from the near fields
    dset.compute_fourier_transforms(**fourier_settings)
    
    # Export and save the dataset
    dset.export(**export_settings)
    
    # Clear the display
    clear_output(wait=False)
# Out:
# Computed TM row 1/16
# Computed TM row 2/16
# Computed TM row 3/16
# Computed TM row 4/16
# Computed TM row 5/16
# Computed TM row 6/16
# Computed TM row 7/16
# Computed TM row 8/16
# Computed TM row 9/16
# Computed TM row 10/16
# Computed TM row 11/16
# Computed TM row 12/16
# Computed TM row 13/16
# Computed TM row 14/16
# Computed TM row 15/16
# Computed TM row 16/16
# Computed couple 1/5000
# Computed couple 2/5000
# Computed couple 3/5000
# Computed couple 4/5000
# Computed couple 5/5000
# Computed couple 6/5000
# Computed couple 7/5000
# Computed couple 8/5000
# Computed couple 9/5000
# Computed couple 10/5000
# Computed couple 11/5000
# Computed couple 12/5000
# Computed couple 13/5000
# Computed couple 14/5000
# Computed couple 15/5000
# Computed couple 16/5000
# Computed couple 17/5000
# Computed couple 18/5000
# Computed couple 19/5000
# Computed couple 20/5000
# Computed couple 21/5000
# Computed couple 22/5000
# Computed couple 23/5000
# Computed couple 24/5000
# Computed couple 25/5000
# Computed couple 26/5000
# Computed couple 27/5000
# Computed couple 28/5000
# Computed couple 29/5000
# Computed couple 30/5000
# Computed couple 31/5000
# Computed couple 32/5000
# Computed couple 33/5000
# Computed couple 34/5000
# Computed couple 35/5000
# Computed couple 36/5000
# Computed couple 37/5000
# Computed couple 38/5000
# Computed couple 39/5000
# Computed couple 40/5000
# Computed couple 41/5000
# Computed couple 42/5000
# Computed couple 43/5000
# Computed couple 44/5000
# Computed couple 45/5000
# Computed couple 46/5000
# Computed couple 47/5000
# Computed couple 48/5000
# Computed couple 49/5000
# Computed couple 50/5000
# Computed couple 51/5000
# Computed couple 52/5000
# Computed couple 53/5000
# Computed couple 54/5000
# Computed couple 55/5000
# Computed couple 56/5000
# Computed couple 57/5000
# Computed couple 58/5000
# Computed couple 59/5000
# Computed couple 60/5000
# Computed couple 61/5000
# Computed couple 62/5000
# Computed couple 63/5000
# Computed couple 64/5000
# Computed couple 65/5000
# Computed couple 66/5000
# Computed couple 67/5000
# Computed couple 68/5000
# Computed couple 69/5000
# Computed couple 70/5000
# Computed couple 71/5000
# Computed couple 72/5000
# Computed couple 73/5000
# Computed couple 74/5000
# Computed couple 75/5000
# Computed couple 76/5000
# Computed couple 77/5000
# Computed couple 78/5000
# Computed couple 79/5000
# Computed couple 80/5000
# Computed couple 81/5000
# Computed couple 82/5000
# Computed couple 83/5000
# Computed couple 84/5000
# Computed couple 85/5000
# Computed couple 86/5000
# Computed couple 87/5000
# Computed couple 88/5000
# Computed couple 89/5000
# Computed couple 90/5000
# Computed couple 91/5000
# Computed couple 92/5000
# Computed couple 93/5000
# Computed couple 94/5000
# Computed couple 95/5000
# Computed couple 96/5000
# Computed couple 97/5000
# Computed couple 98/5000
# Computed couple 99/5000
# Computed couple 100/5000
# Computed couple 101/5000
# Computed couple 102/5000
# Computed couple 103/5000
# Computed couple 104/5000
# Computed couple 105/5000
# Computed couple 106/5000
# Computed couple 107/5000
# Computed couple 108/5000
# Computed couple 109/5000
# Computed couple 110/5000
# Computed couple 111/5000
# Computed couple 112/5000
# Computed couple 113/5000
# Computed couple 114/5000
# Computed couple 115/5000
# Computed couple 116/5000
# Computed couple 117/5000
# Computed couple 118/5000
# Computed couple 119/5000
# Computed couple 120/5000
# Computed couple 121/5000
# Computed couple 122/5000
# Computed couple 123/5000
# Computed couple 124/5000
# Computed couple 125/5000
# Computed couple 126/5000
# Computed couple 127/5000
# Computed couple 128/5000
# Computed couple 129/5000
# Computed couple 130/5000
# Computed couple 131/5000
# Computed couple 132/5000
# Computed couple 133/5000
# Computed couple 134/5000
# Computed couple 135/5000
# Computed couple 136/5000
# Computed couple 137/5000
# Computed couple 138/5000
# Computed couple 139/5000
# Computed couple 140/5000
# Computed couple 141/5000
# Computed couple 142/5000
# Computed couple 143/5000
# Computed couple 144/5000
# Computed couple 145/5000
# Computed couple 146/5000
# Computed couple 147/5000
# Computed couple 148/5000
# Computed couple 149/5000
# Computed couple 150/5000
# Computed couple 151/5000
# Computed couple 152/5000
# Computed couple 153/5000
# Computed couple 154/5000
# Computed couple 155/5000
# Computed couple 156/5000
# Computed couple 157/5000
# Computed couple 158/5000
# Computed couple 159/5000
# Computed couple 160/5000
# Computed couple 161/5000
# Computed couple 162/5000
# Computed couple 163/5000
# Computed couple 164/5000
# Computed couple 165/5000
# Computed couple 166/5000
# Computed couple 167/5000
# Computed couple 168/5000
# Computed couple 169/5000
# Computed couple 170/5000
# Computed couple 171/5000
# Computed couple 172/5000
# Computed couple 173/5000
# Computed couple 174/5000
# Computed couple 175/5000
# Computed couple 176/5000
# Computed couple 177/5000
# Computed couple 178/5000
# Computed couple 179/5000
# Computed couple 180/5000
# Computed couple 181/5000
# Computed couple 182/5000
# Computed couple 183/5000
# Computed couple 184/5000
# Computed couple 185/5000
# Computed couple 186/5000
# Computed couple 187/5000
# Computed couple 188/5000
# Computed couple 189/5000
# Computed couple 190/5000
# Computed couple 191/5000
# Computed couple 192/5000
# Computed couple 193/5000
# Computed couple 194/5000
# Computed couple 195/5000
# Computed couple 196/5000
# Computed couple 197/5000
# Computed couple 198/5000
# Computed couple 199/5000
# Computed couple 200/5000
# Computed couple 201/5000
# Computed couple 202/5000
# Computed couple 203/5000
# Computed couple 204/5000
# Computed couple 205/5000
# Computed couple 206/5000
# Computed couple 207/5000
# Computed couple 208/5000
# Computed couple 209/5000
# Computed couple 210/5000
# Computed couple 211/5000
# Computed couple 212/5000
# Computed couple 213/5000
# Computed couple 214/5000
# Computed couple 215/5000
# Computed couple 216/5000
# Computed couple 217/5000
# Computed couple 218/5000
# Computed couple 219/5000
# Computed couple 220/5000
# Computed couple 221/5000
# Computed couple 222/5000
# Computed couple 223/5000
# Computed couple 224/5000
# Computed couple 225/5000
# Computed couple 226/5000
# Computed couple 227/5000
# Computed couple 228/5000
# Computed couple 229/5000
# Computed couple 230/5000
# Computed couple 231/5000
# Computed couple 232/5000
# Computed couple 233/5000
# Computed couple 234/5000
# Computed couple 235/5000
# Computed couple 236/5000
# Computed couple 237/5000
# Computed couple 238/5000
# Computed couple 239/5000
# Computed couple 240/5000
# Computed couple 241/5000
# Computed couple 242/5000
# Computed couple 243/5000
# Computed couple 244/5000
# Computed couple 245/5000
# Computed couple 246/5000
# Computed couple 247/5000
# Computed couple 248/5000
# Computed couple 249/5000
# Computed couple 250/5000
# Computed couple 251/5000
# Computed couple 252/5000
# Computed couple 253/5000
# Computed couple 254/5000
# Computed couple 255/5000
# Computed couple 256/5000
# Computed couple 257/5000
# Computed couple 258/5000
# Computed couple 259/5000
# Computed couple 260/5000
# Computed couple 261/5000
# Computed couple 262/5000
# Computed couple 263/5000
# Computed couple 264/5000
# Computed couple 265/5000
# Computed couple 266/5000
# Computed couple 267/5000
# Computed couple 268/5000
# Computed couple 269/5000
# Computed couple 270/5000
# Computed couple 271/5000
# Computed couple 272/5000
# Computed couple 273/5000
# Computed couple 274/5000
# Computed couple 275/5000
# Computed couple 276/5000
# Computed couple 277/5000
# Computed couple 278/5000
# Computed couple 279/5000
# Computed couple 280/5000
# Computed couple 281/5000
# Computed couple 282/5000
# Computed couple 283/5000
# Computed couple 284/5000
# Computed couple 285/5000
# Computed couple 286/5000
# Computed couple 287/5000
# Computed couple 288/5000
# Computed couple 289/5000
# Computed couple 290/5000
# Computed couple 291/5000
# Computed couple 292/5000
# Computed couple 293/5000
# Computed couple 294/5000
# Computed couple 295/5000
# Computed couple 296/5000
# Computed couple 297/5000
# Computed couple 298/5000
# Computed couple 299/5000
# Computed couple 300/5000
# Computed couple 301/5000
# Computed couple 302/5000
# Computed couple 303/5000
# Computed couple 304/5000
# Computed couple 305/5000
# Computed couple 306/5000
# Computed couple 307/5000
# Computed couple 308/5000
# Computed couple 309/5000
# Computed couple 310/5000
# Computed couple 311/5000
# Computed couple 312/5000
# Computed couple 313/5000
# Computed couple 314/5000
# Computed couple 315/5000
# Computed couple 316/5000
# Computed couple 317/5000
# Computed couple 318/5000
# Computed couple 319/5000
# Computed couple 320/5000
# Computed couple 321/5000
# Computed couple 322/5000
# Computed couple 323/5000
# Computed couple 324/5000
# Computed couple 325/5000
# Computed couple 326/5000
# Computed couple 327/5000
# Computed couple 328/5000
# Computed couple 329/5000
# Computed couple 330/5000
# Computed couple 331/5000
# Computed couple 332/5000
# Computed couple 333/5000
# Computed couple 334/5000
# Computed couple 335/5000
# Computed couple 336/5000
# Computed couple 337/5000
# Computed couple 338/5000
# Computed couple 339/5000
# Computed couple 340/5000
# Computed couple 341/5000
# Computed couple 342/5000
# Computed couple 343/5000
# Computed couple 344/5000
# Computed couple 345/5000
# Computed couple 346/5000
# Computed couple 347/5000
# Computed couple 348/5000
# Computed couple 349/5000
# Computed couple 350/5000
# Computed couple 351/5000
# Computed couple 352/5000
# Computed couple 353/5000
# Computed couple 354/5000
# Computed couple 355/5000
# Computed couple 356/5000
# Computed couple 357/5000
# Computed couple 358/5000
# Computed couple 359/5000
# Computed couple 360/5000
# Computed couple 361/5000
# Computed couple 362/5000
# Computed couple 363/5000
# Computed couple 364/5000
# Computed couple 365/5000
# Computed couple 366/5000
# Computed couple 367/5000
# Computed couple 368/5000
# Computed couple 369/5000
# Computed couple 370/5000
# Computed couple 371/5000
# Computed couple 372/5000
# Computed couple 373/5000
# Computed couple 374/5000
# Computed couple 375/5000
# Computed couple 376/5000
# Computed couple 377/5000
# Computed couple 378/5000
# Computed couple 379/5000
# Computed couple 380/5000
# Computed couple 381/5000
# Computed couple 382/5000
# Computed couple 383/5000
# Computed couple 384/5000
# Computed couple 385/5000
# Computed couple 386/5000
# Computed couple 387/5000
# Computed couple 388/5000
# Computed couple 389/5000
# Computed couple 390/5000
# Computed couple 391/5000
# Computed couple 392/5000
# Computed couple 393/5000
# Computed couple 394/5000
# Computed couple 395/5000
# Computed couple 396/5000
# Computed couple 397/5000
# Computed couple 398/5000
# Computed couple 399/5000
# Computed couple 400/5000
# Computed couple 401/5000
# Computed couple 402/5000
# Computed couple 403/5000
# Computed couple 404/5000
# Computed couple 405/5000
# Computed couple 406/5000
# Computed couple 407/5000
# Computed couple 408/5000
# Computed couple 409/5000
# Computed couple 410/5000
# Computed couple 411/5000
# Computed couple 412/5000
# Computed couple 413/5000
# Computed couple 414/5000
# Computed couple 415/5000
# Computed couple 416/5000
# Computed couple 417/5000
# Computed couple 418/5000
# Computed couple 419/5000
# Computed couple 420/5000
# Computed couple 421/5000
# Computed couple 422/5000
# Computed couple 423/5000
# Computed couple 424/5000
# Computed couple 425/5000
# Computed couple 426/5000
# Computed couple 427/5000
# Computed couple 428/5000
# Computed couple 429/5000
# Computed couple 430/5000
# Computed couple 431/5000
# Computed couple 432/5000
# Computed couple 433/5000
# Computed couple 434/5000
# Computed couple 435/5000
# Computed couple 436/5000
# Computed couple 437/5000
# Computed couple 438/5000
# Computed couple 439/5000
# Computed couple 440/5000
# Computed couple 441/5000
# Computed couple 442/5000
# Computed couple 443/5000
# Computed couple 444/5000
# Computed couple 445/5000
# Computed couple 446/5000
# Computed couple 447/5000
# Computed couple 448/5000
# Computed couple 449/5000
# Computed couple 450/5000
# Computed couple 451/5000
# Computed couple 452/5000
# Computed couple 453/5000
# Computed couple 454/5000
# Computed couple 455/5000
# Computed couple 456/5000
# Computed couple 457/5000
# Computed couple 458/5000
# Computed couple 459/5000
# Computed couple 460/5000
# Computed couple 461/5000
# Computed couple 462/5000
# Computed couple 463/5000
# Computed couple 464/5000
# Computed couple 465/5000
# Computed couple 466/5000
# Computed couple 467/5000
# Computed couple 468/5000
# Computed couple 469/5000
# Computed couple 470/5000
# Computed couple 471/5000
# Computed couple 472/5000
# Computed couple 473/5000
# Computed couple 474/5000
# Computed couple 475/5000
# Computed couple 476/5000
# Computed couple 477/5000
# Computed couple 478/5000
# Computed couple 479/5000
# Computed couple 480/5000
# Computed couple 481/5000
# Computed couple 482/5000
# Computed couple 483/5000
# Computed couple 484/5000
# Computed couple 485/5000
# Computed couple 486/5000
# Computed couple 487/5000
# Computed couple 488/5000
# Computed couple 489/5000
# Computed couple 490/5000
# Computed couple 491/5000
# Computed couple 492/5000
# Computed couple 493/5000
# Computed couple 494/5000
# Computed couple 495/5000
# Computed couple 496/5000
# Computed couple 497/5000
# Computed couple 498/5000
# Computed couple 499/5000
# Computed couple 500/5000
# Computed couple 501/5000
# Computed couple 502/5000
# Computed couple 503/5000
# Computed couple 504/5000
# Computed couple 505/5000
# Computed couple 506/5000
# Computed couple 507/5000
# Computed couple 508/5000
# Computed couple 509/5000
# Computed couple 510/5000
# Computed couple 511/5000
# Computed couple 512/5000
# Computed couple 513/5000
# Computed couple 514/5000
# Computed couple 515/5000
# Computed couple 516/5000
# Computed couple 517/5000
# Computed couple 518/5000
# Computed couple 519/5000
# Computed couple 520/5000
# Computed couple 521/5000
# Computed couple 522/5000
# Computed couple 523/5000
# Computed couple 524/5000
# Computed couple 525/5000
# Computed couple 526/5000
# Computed couple 527/5000
# Computed couple 528/5000
# Computed couple 529/5000
# Computed couple 530/5000
# Computed couple 531/5000
# Computed couple 532/5000
# Computed couple 533/5000
# Computed couple 534/5000
# Computed couple 535/5000
# Computed couple 536/5000
# Computed couple 537/5000
# Computed couple 538/5000
# Computed couple 539/5000
# Computed couple 540/5000
# Computed couple 541/5000
# Computed couple 542/5000
# Computed couple 543/5000
# Computed couple 544/5000
# Computed couple 545/5000
# Computed couple 546/5000
# Computed couple 547/5000
# Computed couple 548/5000
# Computed couple 549/5000
# Computed couple 550/5000
# Computed couple 551/5000
# Computed couple 552/5000
# Computed couple 553/5000
# Computed couple 554/5000
# Computed couple 555/5000
# Computed couple 556/5000
# Computed couple 557/5000
# Computed couple 558/5000
# Computed couple 559/5000
# Computed couple 560/5000
# Computed couple 561/5000
# Computed couple 562/5000
# Computed couple 563/5000
# Computed couple 564/5000
# Computed couple 565/5000
# Computed couple 566/5000
# Computed couple 567/5000
# Computed couple 568/5000
# Computed couple 569/5000
# Computed couple 570/5000
# Computed couple 571/5000
# Computed couple 572/5000
# Computed couple 573/5000
# Computed couple 574/5000
# Computed couple 575/5000
# Computed couple 576/5000
# Computed couple 577/5000
# Computed couple 578/5000
# Computed couple 579/5000
# Computed couple 580/5000
# Computed couple 581/5000
# Computed couple 582/5000
# Computed couple 583/5000
# Computed couple 584/5000
# Computed couple 585/5000
# Computed couple 586/5000
# Computed couple 587/5000
# Computed couple 588/5000
# Computed couple 589/5000
# Computed couple 590/5000
# Computed couple 591/5000
# Computed couple 592/5000
# Computed couple 593/5000
# Computed couple 594/5000
# Computed couple 595/5000
# Computed couple 596/5000
# Computed couple 597/5000
# Computed couple 598/5000
# Computed couple 599/5000
# Computed couple 600/5000
# Computed couple 601/5000
# Computed couple 602/5000
# Computed couple 603/5000
# Computed couple 604/5000
# Computed couple 605/5000
# Computed couple 606/5000
# Computed couple 607/5000
# Computed couple 608/5000
# Computed couple 609/5000
# Computed couple 610/5000
# Computed couple 611/5000
# Computed couple 612/5000
# Computed couple 613/5000
# Computed couple 614/5000
# Computed couple 615/5000
# Computed couple 616/5000
# Computed couple 617/5000
# Computed couple 618/5000
# Computed couple 619/5000
# Computed couple 620/5000
# Computed couple 621/5000
# Computed couple 622/5000
# Computed couple 623/5000
# Computed couple 624/5000
# Computed couple 625/5000
# Computed couple 626/5000
# Computed couple 627/5000
# Computed couple 628/5000
# Computed couple 629/5000
# Computed couple 630/5000
# Computed couple 631/5000
# Computed couple 632/5000
# Computed couple 633/5000
# Computed couple 634/5000
# Computed couple 635/5000
# Computed couple 636/5000
# Computed couple 637/5000
# Computed couple 638/5000
# Computed couple 639/5000
# Computed couple 640/5000
# Computed couple 641/5000
# Computed couple 642/5000
# Computed couple 643/5000
# Computed couple 644/5000
# Computed couple 645/5000
# Computed couple 646/5000
# Computed couple 647/5000
# Computed couple 648/5000
# Computed couple 649/5000
# Computed couple 650/5000
# Computed couple 651/5000
# Computed couple 652/5000
# Computed couple 653/5000
# Computed couple 654/5000
# Computed couple 655/5000
# Computed couple 656/5000
# Computed couple 657/5000
# Computed couple 658/5000
# Computed couple 659/5000
# Computed couple 660/5000
# Computed couple 661/5000
# Computed couple 662/5000
# Computed couple 663/5000
# Computed couple 664/5000
# Computed couple 665/5000
# Computed couple 666/5000
# Computed couple 667/5000
# Computed couple 668/5000
# Computed couple 669/5000
# Computed couple 670/5000
# Computed couple 671/5000
# Computed couple 672/5000
# Computed couple 673/5000
# Computed couple 674/5000
# Computed couple 675/5000
# Computed couple 676/5000
# Computed couple 677/5000
# Computed couple 678/5000
# Computed couple 679/5000
# Computed couple 680/5000
# Computed couple 681/5000
# Computed couple 682/5000
# Computed couple 683/5000
# Computed couple 684/5000
# Computed couple 685/5000
# Computed couple 686/5000
# Computed couple 687/5000
# Computed couple 688/5000
# Computed couple 689/5000
# Computed couple 690/5000
# Computed couple 691/5000
# Computed couple 692/5000
# Computed couple 693/5000
# Computed couple 694/5000
# Computed couple 695/5000
# Computed couple 696/5000
# Computed couple 697/5000
# Computed couple 698/5000
# Computed couple 699/5000
# Computed couple 700/5000
# Computed couple 701/5000
# Computed couple 702/5000
# Computed couple 703/5000
# Computed couple 704/5000
# Computed couple 705/5000
# Computed couple 706/5000
# Computed couple 707/5000
# Computed couple 708/5000
# Computed couple 709/5000
# Computed couple 710/5000
# Computed couple 711/5000
# Computed couple 712/5000
# Computed couple 713/5000
# Computed couple 714/5000
# Computed couple 715/5000
# Computed couple 716/5000
# Computed couple 717/5000
# Computed couple 718/5000
# Computed couple 719/5000
# Computed couple 720/5000
# Computed couple 721/5000
# Computed couple 722/5000
# Computed couple 723/5000
# Computed couple 724/5000
# Computed couple 725/5000
# Computed couple 726/5000
# Computed couple 727/5000
# Computed couple 728/5000
# Computed couple 729/5000
# Computed couple 730/5000
# Computed couple 731/5000
# Computed couple 732/5000
# Computed couple 733/5000
# Computed couple 734/5000
# Computed couple 735/5000
# Computed couple 736/5000
# Computed couple 737/5000
# Computed couple 738/5000
# Computed couple 739/5000
# Computed couple 740/5000
# Computed couple 741/5000
# Computed couple 742/5000
# Computed couple 743/5000
# Computed couple 744/5000
# Computed couple 745/5000
# Computed couple 746/5000
# Computed couple 747/5000
# Computed couple 748/5000
# Computed couple 749/5000
# Computed couple 750/5000
# Computed couple 751/5000
# Computed couple 752/5000
# Computed couple 753/5000
# Computed couple 754/5000
# Computed couple 755/5000
# Computed couple 756/5000
# Computed couple 757/5000
# Computed couple 758/5000
# Computed couple 759/5000
# Computed couple 760/5000
# Computed couple 761/5000
# Computed couple 762/5000
# Computed couple 763/5000
# Computed couple 764/5000
# Computed couple 765/5000
# Computed couple 766/5000
# Computed couple 767/5000
# Computed couple 768/5000
# Computed couple 769/5000
# Computed couple 770/5000
# Computed couple 771/5000
# Computed couple 772/5000
# Computed couple 773/5000
# Computed couple 774/5000
# Computed couple 775/5000
# Computed couple 776/5000
# Computed couple 777/5000
# Computed couple 778/5000
# Computed couple 779/5000
# Computed couple 780/5000
# Computed couple 781/5000
# Computed couple 782/5000
# Computed couple 783/5000
# Computed couple 784/5000
# Computed couple 785/5000
# Computed couple 786/5000
# Computed couple 787/5000
# Computed couple 788/5000
# Computed couple 789/5000
# Computed couple 790/5000
# Computed couple 791/5000
# Computed couple 792/5000
# Computed couple 793/5000
# Computed couple 794/5000
# Computed couple 795/5000
# Computed couple 796/5000
# Computed couple 797/5000
# Computed couple 798/5000
# Computed couple 799/5000
# Computed couple 800/5000
# Computed couple 801/5000
# Computed couple 802/5000
# Computed couple 803/5000
# Computed couple 804/5000
# Computed couple 805/5000
# Computed couple 806/5000
# Computed couple 807/5000
# Computed couple 808/5000
# Computed couple 809/5000
# Computed couple 810/5000
# Computed couple 811/5000
# Computed couple 812/5000
# Computed couple 813/5000
# Computed couple 814/5000
# Computed couple 815/5000
# Computed couple 816/5000
# Computed couple 817/5000
# Computed couple 818/5000
# Computed couple 819/5000
# Computed couple 820/5000
# Computed couple 821/5000
# Computed couple 822/5000
# Computed couple 823/5000
# Computed couple 824/5000
# Computed couple 825/5000
# Computed couple 826/5000
# Computed couple 827/5000
# Computed couple 828/5000
# Computed couple 829/5000
# Computed couple 830/5000
# Computed couple 831/5000
# Computed couple 832/5000
# Computed couple 833/5000
# Computed couple 834/5000
# Computed couple 835/5000
# Computed couple 836/5000
# Computed couple 837/5000
# Computed couple 838/5000
# Computed couple 839/5000
# Computed couple 840/5000
# Computed couple 841/5000
# Computed couple 842/5000
# Computed couple 843/5000
# Computed couple 844/5000
# Computed couple 845/5000
# Computed couple 846/5000
# Computed couple 847/5000
# Computed couple 848/5000
# Computed couple 849/5000
# Computed couple 850/5000
# Computed couple 851/5000
# Computed couple 852/5000
# Computed couple 853/5000
# Computed couple 854/5000
# Computed couple 855/5000
# Computed couple 856/5000
# Computed couple 857/5000
# Computed couple 858/5000
# Computed couple 859/5000
# Computed couple 860/5000
# Computed couple 861/5000
# Computed couple 862/5000
# Computed couple 863/5000
# Computed couple 864/5000
# Computed couple 865/5000
# Computed couple 866/5000
# Computed couple 867/5000
# Computed couple 868/5000
# Computed couple 869/5000
# Computed couple 870/5000
# Computed couple 871/5000
# Computed couple 872/5000
# Computed couple 873/5000
# Computed couple 874/5000
# Computed couple 875/5000
# Computed couple 876/5000
# Computed couple 877/5000
# Computed couple 878/5000
# Computed couple 879/5000
# Computed couple 880/5000
# Computed couple 881/5000
# Computed couple 882/5000
# Computed couple 883/5000
# Computed couple 884/5000
# Computed couple 885/5000
# Computed couple 886/5000
# Computed couple 887/5000
# Computed couple 888/5000
# Computed couple 889/5000
# Computed couple 890/5000
# Computed couple 891/5000
# Computed couple 892/5000
# Computed couple 893/5000
# Computed couple 894/5000
# Computed couple 895/5000
# Computed couple 896/5000
# Computed couple 897/5000
# Computed couple 898/5000
# Computed couple 899/5000
# Computed couple 900/5000
# Computed couple 901/5000
# Computed couple 902/5000
# Computed couple 903/5000
# Computed couple 904/5000
# Computed couple 905/5000
# Computed couple 906/5000
# Computed couple 907/5000
# Computed couple 908/5000
# Computed couple 909/5000
# Computed couple 910/5000
# Computed couple 911/5000
# Computed couple 912/5000
# Computed couple 913/5000
# Computed couple 914/5000
# Computed couple 915/5000
# Computed couple 916/5000
# Computed couple 917/5000
# Computed couple 918/5000
# Computed couple 919/5000
# Computed couple 920/5000
# Computed couple 921/5000
# Computed couple 922/5000
# Computed couple 923/5000
# Computed couple 924/5000
# Computed couple 925/5000
# Computed couple 926/5000
# Computed couple 927/5000
# Computed couple 928/5000
# Computed couple 929/5000
# Computed couple 930/5000
# Computed couple 931/5000
# Computed couple 932/5000
# Computed couple 933/5000
# Computed couple 934/5000
# Computed couple 935/5000
# Computed couple 936/5000
# Computed couple 937/5000
# Computed couple 938/5000
# Computed couple 939/5000
# Computed couple 940/5000
# Computed couple 941/5000
# Computed couple 942/5000
# Computed couple 943/5000
# Computed couple 944/5000
# Computed couple 945/5000
# Computed couple 946/5000
# Computed couple 947/5000
# Computed couple 948/5000
# Computed couple 949/5000
# Computed couple 950/5000
# Computed couple 951/5000
# Computed couple 952/5000
# Computed couple 953/5000
# Computed couple 954/5000
# Computed couple 955/5000
# Computed couple 956/5000
# Computed couple 957/5000
# Computed couple 958/5000
# Computed couple 959/5000
# Computed couple 960/5000
# Computed couple 961/5000
# Computed couple 962/5000
# Computed couple 963/5000
# Computed couple 964/5000
# Computed couple 965/5000
# Computed couple 966/5000
# Computed couple 967/5000
# Computed couple 968/5000
# Computed couple 969/5000
# Computed couple 970/5000
# Computed couple 971/5000
# Computed couple 972/5000
# Computed couple 973/5000
# Computed couple 974/5000
# Computed couple 975/5000
# Computed couple 976/5000
# Computed couple 977/5000
# Computed couple 978/5000
# Computed couple 979/5000
# Computed couple 980/5000
# Computed couple 981/5000
# Computed couple 982/5000
# Computed couple 983/5000
# Computed couple 984/5000
# Computed couple 985/5000
# Computed couple 986/5000
# Computed couple 987/5000
# Computed couple 988/5000
# Computed couple 989/5000
# Computed couple 990/5000
# Computed couple 991/5000
# Computed couple 992/5000
# Computed couple 993/5000
# Computed couple 994/5000
# Computed couple 995/5000
# Computed couple 996/5000
# Computed couple 997/5000
# Computed couple 998/5000
# Computed couple 999/5000
# Computed couple 1000/5000
# Computed couple 1001/5000
# Computed couple 1002/5000
# Computed couple 1003/5000
# Computed couple 1004/5000
# Computed couple 1005/5000
# Computed couple 1006/5000
# Computed couple 1007/5000
# Computed couple 1008/5000
# Computed couple 1009/5000
# Computed couple 1010/5000
# Computed couple 1011/5000
# Computed couple 1012/5000
# Computed couple 1013/5000
# Computed couple 1014/5000
# Computed couple 1015/5000
# Computed couple 1016/5000
# Computed couple 1017/5000
# Computed couple 1018/5000
# Computed couple 1019/5000
# Computed couple 1020/5000
# Computed couple 1021/5000
# Computed couple 1022/5000
# Computed couple 1023/5000
# Computed couple 1024/5000
# Computed couple 1025/5000
# Computed couple 1026/5000
# Computed couple 1027/5000
# Computed couple 1028/5000
# Computed couple 1029/5000
# Computed couple 1030/5000
# Computed couple 1031/5000
# Computed couple 1032/5000
# Computed couple 1033/5000
# Computed couple 1034/5000
# Computed couple 1035/5000
# Computed couple 1036/5000
# Computed couple 1037/5000
# Computed couple 1038/5000
# Computed couple 1039/5000
# Computed couple 1040/5000
# Computed couple 1041/5000
# Computed couple 1042/5000
# Computed couple 1043/5000
# Computed couple 1044/5000
# Computed couple 1045/5000
# Computed couple 1046/5000
# Computed couple 1047/5000
# Computed couple 1048/5000
# Computed couple 1049/5000
# Computed couple 1050/5000
# Computed couple 1051/5000
# Computed couple 1052/5000
# Computed couple 1053/5000
# Computed couple 1054/5000
# Computed couple 1055/5000
# Computed couple 1056/5000
# Computed couple 1057/5000
# Computed couple 1058/5000
# Computed couple 1059/5000
# Computed couple 1060/5000
# Computed couple 1061/5000
# Computed couple 1062/5000
# Computed couple 1063/5000
# Computed couple 1064/5000
# Computed couple 1065/5000
# Computed couple 1066/5000
# Computed couple 1067/5000
# Computed couple 1068/5000
# Computed couple 1069/5000
# Computed couple 1070/5000
# Computed couple 1071/5000
# Computed couple 1072/5000
# Computed couple 1073/5000
# Computed couple 1074/5000
# Computed couple 1075/5000
# Computed couple 1076/5000
# Computed couple 1077/5000
# Computed couple 1078/5000
# Computed couple 1079/5000
# Computed couple 1080/5000
# Computed couple 1081/5000
# Computed couple 1082/5000
# Computed couple 1083/5000
# Computed couple 1084/5000
# Computed couple 1085/5000
# Computed couple 1086/5000
# Computed couple 1087/5000
# Computed couple 1088/5000
# Computed couple 1089/5000
# Computed couple 1090/5000
# Computed couple 1091/5000
# Computed couple 1092/5000
# Computed couple 1093/5000
# Computed couple 1094/5000
# Computed couple 1095/5000
# Computed couple 1096/5000
# Computed couple 1097/5000
# Computed couple 1098/5000
# Computed couple 1099/5000
# Computed couple 1100/5000
# Computed couple 1101/5000
# Computed couple 1102/5000
# Computed couple 1103/5000
# Computed couple 1104/5000
# Computed couple 1105/5000
# Computed couple 1106/5000
# Computed couple 1107/5000
# Computed couple 1108/5000
# Computed couple 1109/5000
# Computed couple 1110/5000
# Computed couple 1111/5000
# Computed couple 1112/5000
# Computed couple 1113/5000
# Computed couple 1114/5000
# Computed couple 1115/5000
# Computed couple 1116/5000
# Computed couple 1117/5000
# Computed couple 1118/5000
# Computed couple 1119/5000
# Computed couple 1120/5000
# Computed couple 1121/5000
# Computed couple 1122/5000
# Computed couple 1123/5000
# Computed couple 1124/5000
# Computed couple 1125/5000
# Computed couple 1126/5000
# Computed couple 1127/5000
# Computed couple 1128/5000
# Computed couple 1129/5000
# Computed couple 1130/5000
# Computed couple 1131/5000
# Computed couple 1132/5000
# Computed couple 1133/5000
# Computed couple 1134/5000
# Computed couple 1135/5000
# Computed couple 1136/5000
# Computed couple 1137/5000
# Computed couple 1138/5000
# Computed couple 1139/5000
# Computed couple 1140/5000
# Computed couple 1141/5000
# Computed couple 1142/5000
# Computed couple 1143/5000
# Computed couple 1144/5000
# Computed couple 1145/5000
# Computed couple 1146/5000
# Computed couple 1147/5000
# Computed couple 1148/5000
# Computed couple 1149/5000
# Computed couple 1150/5000
# Computed couple 1151/5000
# Computed couple 1152/5000
# Computed couple 1153/5000
# Computed couple 1154/5000
# Computed couple 1155/5000
# Computed couple 1156/5000
# Computed couple 1157/5000
# Computed couple 1158/5000
# Computed couple 1159/5000
# Computed couple 1160/5000
# Computed couple 1161/5000
# Computed couple 1162/5000
# Computed couple 1163/5000
# Computed couple 1164/5000
# Computed couple 1165/5000
# Computed couple 1166/5000
# Computed couple 1167/5000
# Computed couple 1168/5000
# Computed couple 1169/5000
# Computed couple 1170/5000
# Computed couple 1171/5000
# Computed couple 1172/5000
# Computed couple 1173/5000
# Computed couple 1174/5000
# Computed couple 1175/5000
# Computed couple 1176/5000
# Computed couple 1177/5000
# Computed couple 1178/5000
# Computed couple 1179/5000
# Computed couple 1180/5000
# Computed couple 1181/5000
# Computed couple 1182/5000
# Computed couple 1183/5000
# Computed couple 1184/5000
# Computed couple 1185/5000
# Computed couple 1186/5000
# Computed couple 1187/5000
# Computed couple 1188/5000
# Computed couple 1189/5000
# Computed couple 1190/5000
# Computed couple 1191/5000
# Computed couple 1192/5000
# Computed couple 1193/5000
# Computed couple 1194/5000
# Computed couple 1195/5000
# Computed couple 1196/5000
# Computed couple 1197/5000
# Computed couple 1198/5000
# Computed couple 1199/5000
# Computed couple 1200/5000
# Computed couple 1201/5000
# Computed couple 1202/5000
# Computed couple 1203/5000
# Computed couple 1204/5000
# Computed couple 1205/5000
# Computed couple 1206/5000
# Computed couple 1207/5000
# Computed couple 1208/5000
# Computed couple 1209/5000
# Computed couple 1210/5000
# Computed couple 1211/5000
# Computed couple 1212/5000
# Computed couple 1213/5000
# Computed couple 1214/5000
# Computed couple 1215/5000
# Computed couple 1216/5000
# Computed couple 1217/5000
# Computed couple 1218/5000
# Computed couple 1219/5000
# Computed couple 1220/5000
# Computed couple 1221/5000
# Computed couple 1222/5000
# Computed couple 1223/5000
# Computed couple 1224/5000
# Computed couple 1225/5000
# Computed couple 1226/5000
# Computed couple 1227/5000
# Computed couple 1228/5000
# Computed couple 1229/5000
# Computed couple 1230/5000
# Computed couple 1231/5000
# Computed couple 1232/5000
# Computed couple 1233/5000
# Computed couple 1234/5000
# Computed couple 1235/5000
# Computed couple 1236/5000
# Computed couple 1237/5000
# Computed couple 1238/5000
# Computed couple 1239/5000
# Computed couple 1240/5000
# Computed couple 1241/5000
# Computed couple 1242/5000
# Computed couple 1243/5000
# Computed couple 1244/5000
# Computed couple 1245/5000
# Computed couple 1246/5000
# Computed couple 1247/5000
# Computed couple 1248/5000
# Computed couple 1249/5000
# Computed couple 1250/5000
# Computed couple 1251/5000
# Computed couple 1252/5000
# Computed couple 1253/5000
# Computed couple 1254/5000
# Computed couple 1255/5000
# Computed couple 1256/5000
# Computed couple 1257/5000
# Computed couple 1258/5000
# Computed couple 1259/5000
# Computed couple 1260/5000
# Computed couple 1261/5000
# Computed couple 1262/5000
# Computed couple 1263/5000
# Computed couple 1264/5000
# Computed couple 1265/5000
# Computed couple 1266/5000
# Computed couple 1267/5000
# Computed couple 1268/5000
# Computed couple 1269/5000
# Computed couple 1270/5000
# Computed couple 1271/5000
# Computed couple 1272/5000
# Computed couple 1273/5000
# Computed couple 1274/5000
# Computed couple 1275/5000
# Computed couple 1276/5000
# Computed couple 1277/5000
# Computed couple 1278/5000
# Computed couple 1279/5000
# Computed couple 1280/5000
# Computed couple 1281/5000
# Computed couple 1282/5000
# Computed couple 1283/5000
# Computed couple 1284/5000
# Computed couple 1285/5000
# Computed couple 1286/5000
# Computed couple 1287/5000
# Computed couple 1288/5000
# Computed couple 1289/5000
# Computed couple 1290/5000
# Computed couple 1291/5000
# Computed couple 1292/5000
# Computed couple 1293/5000
# Computed couple 1294/5000
# Computed couple 1295/5000
# Computed couple 1296/5000
# Computed couple 1297/5000
# Computed couple 1298/5000
# Computed couple 1299/5000
# Computed couple 1300/5000
# Computed couple 1301/5000
# Computed couple 1302/5000
# Computed couple 1303/5000
# Computed couple 1304/5000
# Computed couple 1305/5000
# Computed couple 1306/5000
# Computed couple 1307/5000
# Computed couple 1308/5000
# Computed couple 1309/5000
# Computed couple 1310/5000
# Computed couple 1311/5000
# Computed couple 1312/5000
# Computed couple 1313/5000
# Computed couple 1314/5000
# Computed couple 1315/5000
# Computed couple 1316/5000
# Computed couple 1317/5000
# Computed couple 1318/5000
# Computed couple 1319/5000
# Computed couple 1320/5000
# Computed couple 1321/5000
# Computed couple 1322/5000
# Computed couple 1323/5000
# Computed couple 1324/5000
# Computed couple 1325/5000
# Computed couple 1326/5000
# Computed couple 1327/5000
# Computed couple 1328/5000
# Computed couple 1329/5000
# Computed couple 1330/5000
# Computed couple 1331/5000
# Computed couple 1332/5000
# Computed couple 1333/5000
# Computed couple 1334/5000
# Computed couple 1335/5000
# Computed couple 1336/5000
# Computed couple 1337/5000
# Computed couple 1338/5000
# Computed couple 1339/5000
# Computed couple 1340/5000
# Computed couple 1341/5000
# Computed couple 1342/5000
# Computed couple 1343/5000
# Computed couple 1344/5000
# Computed couple 1345/5000
# Computed couple 1346/5000
# Computed couple 1347/5000
# Computed couple 1348/5000
# Computed couple 1349/5000
# Computed couple 1350/5000
# Computed couple 1351/5000
# Computed couple 1352/5000
# Computed couple 1353/5000
# Computed couple 1354/5000
# Computed couple 1355/5000
# Computed couple 1356/5000
# Computed couple 1357/5000
# Computed couple 1358/5000
# Computed couple 1359/5000
# Computed couple 1360/5000
# Computed couple 1361/5000
# Computed couple 1362/5000
# Computed couple 1363/5000
# Computed couple 1364/5000
# Computed couple 1365/5000
# Computed couple 1366/5000
# Computed couple 1367/5000
# Computed couple 1368/5000
# Computed couple 1369/5000
# Computed couple 1370/5000
# Computed couple 1371/5000
# Computed couple 1372/5000
# Computed couple 1373/5000
# Computed couple 1374/5000
# Computed couple 1375/5000
# Computed couple 1376/5000
# Computed couple 1377/5000
# Computed couple 1378/5000
# Computed couple 1379/5000
# Computed couple 1380/5000
# Computed couple 1381/5000
# Computed couple 1382/5000
# Computed couple 1383/5000
# Computed couple 1384/5000
# Computed couple 1385/5000
# Computed couple 1386/5000
# Computed couple 1387/5000
# Computed couple 1388/5000
# Computed couple 1389/5000
# Computed couple 1390/5000
# Computed couple 1391/5000
# Computed couple 1392/5000
# Computed couple 1393/5000
# Computed couple 1394/5000
# Computed couple 1395/5000
# Computed couple 1396/5000
# Computed couple 1397/5000
# Computed couple 1398/5000
# Computed couple 1399/5000
# Computed couple 1400/5000
# Computed couple 1401/5000
# Computed couple 1402/5000
# Computed couple 1403/5000
# Computed couple 1404/5000
# Computed couple 1405/5000
# Computed couple 1406/5000
# Computed couple 1407/5000
# Computed couple 1408/5000
# Computed couple 1409/5000
# Computed couple 1410/5000
# Computed couple 1411/5000
# Computed couple 1412/5000
# Computed couple 1413/5000
# Computed couple 1414/5000
# Computed couple 1415/5000
# Computed couple 1416/5000
# Computed couple 1417/5000
# Computed couple 1418/5000
# Computed couple 1419/5000
# Computed couple 1420/5000
# Computed couple 1421/5000
# Computed couple 1422/5000
# Computed couple 1423/5000
# Computed couple 1424/5000
# Computed couple 1425/5000
# Computed couple 1426/5000
# Computed couple 1427/5000
# Computed couple 1428/5000
# Computed couple 1429/5000
# Computed couple 1430/5000
# Computed couple 1431/5000
# Computed couple 1432/5000
# Computed couple 1433/5000
# Computed couple 1434/5000
# Computed couple 1435/5000
# Computed couple 1436/5000
# Computed couple 1437/5000
# Computed couple 1438/5000
# Computed couple 1439/5000
# Computed couple 1440/5000
# Computed couple 1441/5000
# Computed couple 1442/5000
# Computed couple 1443/5000
# Computed couple 1444/5000
# Computed couple 1445/5000
# Computed couple 1446/5000
# Computed couple 1447/5000
# Computed couple 1448/5000
# Computed couple 1449/5000
# Computed couple 1450/5000
# Computed couple 1451/5000
# Computed couple 1452/5000
# Computed couple 1453/5000
# Computed couple 1454/5000
# Computed couple 1455/5000
# Computed couple 1456/5000
# Computed couple 1457/5000
# Computed couple 1458/5000
# Computed couple 1459/5000
# Computed couple 1460/5000
# Computed couple 1461/5000
# Computed couple 1462/5000
# Computed couple 1463/5000
# Computed couple 1464/5000
# Computed couple 1465/5000
# Computed couple 1466/5000
# Computed couple 1467/5000
# Computed couple 1468/5000
# Computed couple 1469/5000
# Computed couple 1470/5000
# Computed couple 1471/5000
# Computed couple 1472/5000
# Computed couple 1473/5000
# Computed couple 1474/5000
# Computed couple 1475/5000
# Computed couple 1476/5000
# Computed couple 1477/5000
# Computed couple 1478/5000
# Computed couple 1479/5000
# Computed couple 1480/5000
# Computed couple 1481/5000
# Computed couple 1482/5000
# Computed couple 1483/5000
# Computed couple 1484/5000
# Computed couple 1485/5000
# Computed couple 1486/5000
# Computed couple 1487/5000
# Computed couple 1488/5000
# Computed couple 1489/5000
# Computed couple 1490/5000
# Computed couple 1491/5000
# Computed couple 1492/5000
# Computed couple 1493/5000
# Computed couple 1494/5000
# Computed couple 1495/5000
# Computed couple 1496/5000
# Computed couple 1497/5000
# Computed couple 1498/5000
# Computed couple 1499/5000
# Computed couple 1500/5000
# Computed couple 1501/5000
# Computed couple 1502/5000
# Computed couple 1503/5000
# Computed couple 1504/5000
# Computed couple 1505/5000
# Computed couple 1506/5000
# Computed couple 1507/5000
# Computed couple 1508/5000
# Computed couple 1509/5000
# Computed couple 1510/5000
# Computed couple 1511/5000
# Computed couple 1512/5000
# Computed couple 1513/5000
# Computed couple 1514/5000
# Computed couple 1515/5000
# Computed couple 1516/5000
# Computed couple 1517/5000
# Computed couple 1518/5000
# Computed couple 1519/5000
# Computed couple 1520/5000
# Computed couple 1521/5000
# Computed couple 1522/5000
# Computed couple 1523/5000
# Computed couple 1524/5000
# Computed couple 1525/5000
# Computed couple 1526/5000
# Computed couple 1527/5000
# Computed couple 1528/5000
# Computed couple 1529/5000
# Computed couple 1530/5000
# Computed couple 1531/5000
# Computed couple 1532/5000
# Computed couple 1533/5000
# Computed couple 1534/5000
# Computed couple 1535/5000
# Computed couple 1536/5000
# Computed couple 1537/5000
# Computed couple 1538/5000
# Computed couple 1539/5000
# Computed couple 1540/5000
# Computed couple 1541/5000
# Computed couple 1542/5000
# Computed couple 1543/5000
# Computed couple 1544/5000
# Computed couple 1545/5000
# Computed couple 1546/5000
# Computed couple 1547/5000
# Computed couple 1548/5000
# Computed couple 1549/5000
# Computed couple 1550/5000
# Computed couple 1551/5000
# Computed couple 1552/5000
# Computed couple 1553/5000
# Computed couple 1554/5000
# Computed couple 1555/5000
# Computed couple 1556/5000
# Computed couple 1557/5000
# Computed couple 1558/5000
# Computed couple 1559/5000
# Computed couple 1560/5000
# Computed couple 1561/5000
# Computed couple 1562/5000
# Computed couple 1563/5000
# Computed couple 1564/5000
# Computed couple 1565/5000
# Computed couple 1566/5000
# Computed couple 1567/5000
# Computed couple 1568/5000
# Computed couple 1569/5000
# Computed couple 1570/5000
# Computed couple 1571/5000
# Computed couple 1572/5000
# Computed couple 1573/5000
# Computed couple 1574/5000
# Computed couple 1575/5000
# Computed couple 1576/5000
# Computed couple 1577/5000
# Computed couple 1578/5000
# Computed couple 1579/5000
# Computed couple 1580/5000
# Computed couple 1581/5000
# Computed couple 1582/5000
# Computed couple 1583/5000
# Computed couple 1584/5000
# Computed couple 1585/5000
# Computed couple 1586/5000
# Computed couple 1587/5000
# Computed couple 1588/5000
# Computed couple 1589/5000
# Computed couple 1590/5000
# Computed couple 1591/5000
# Computed couple 1592/5000
# Computed couple 1593/5000
# Computed couple 1594/5000
# Computed couple 1595/5000
# Computed couple 1596/5000
# Computed couple 1597/5000
# Computed couple 1598/5000
# Computed couple 1599/5000
# Computed couple 1600/5000
# Computed couple 1601/5000
# Computed couple 1602/5000
# Computed couple 1603/5000
# Computed couple 1604/5000
# Computed couple 1605/5000
# Computed couple 1606/5000
# Computed couple 1607/5000
# Computed couple 1608/5000
# Computed couple 1609/5000
# Computed couple 1610/5000
# Computed couple 1611/5000
# Computed couple 1612/5000
# Computed couple 1613/5000
# Computed couple 1614/5000
# Computed couple 1615/5000
# Computed couple 1616/5000
# Computed couple 1617/5000
# Computed couple 1618/5000
# Computed couple 1619/5000
# Computed couple 1620/5000
# Computed couple 1621/5000
# Computed couple 1622/5000
# Computed couple 1623/5000
# Computed couple 1624/5000
# Computed couple 1625/5000
# Computed couple 1626/5000
# Computed couple 1627/5000
# Computed couple 1628/5000
# Computed couple 1629/5000
# Computed couple 1630/5000
# Computed couple 1631/5000
# Computed couple 1632/5000
# Computed couple 1633/5000
# Computed couple 1634/5000
# Computed couple 1635/5000
# Computed couple 1636/5000
# Computed couple 1637/5000
# Computed couple 1638/5000
# Computed couple 1639/5000
# Computed couple 1640/5000
# Computed couple 1641/5000
# Computed couple 1642/5000
# Computed couple 1643/5000
# Computed couple 1644/5000
# Computed couple 1645/5000
# Computed couple 1646/5000
# Computed couple 1647/5000
# Computed couple 1648/5000
# Computed couple 1649/5000
# Computed couple 1650/5000
# Computed couple 1651/5000
# Computed couple 1652/5000
# Computed couple 1653/5000
# Computed couple 1654/5000
# Computed couple 1655/5000
# Computed couple 1656/5000
# Computed couple 1657/5000
# Computed couple 1658/5000
# Computed couple 1659/5000
# Computed couple 1660/5000
# Computed couple 1661/5000
# Computed couple 1662/5000
# Computed couple 1663/5000
# Computed couple 1664/5000
# Computed couple 1665/5000
# Computed couple 1666/5000
# Computed couple 1667/5000
# Computed couple 1668/5000
# Computed couple 1669/5000
# Computed couple 1670/5000
# Computed couple 1671/5000
# Computed couple 1672/5000
# Computed couple 1673/5000
# Computed couple 1674/5000
# Computed couple 1675/5000
# Computed couple 1676/5000
# Computed couple 1677/5000
# Computed couple 1678/5000
# Computed couple 1679/5000
# Computed couple 1680/5000
# Computed couple 1681/5000
# Computed couple 1682/5000
# Computed couple 1683/5000
# Computed couple 1684/5000
# Computed couple 1685/5000
# Computed couple 1686/5000
# Computed couple 1687/5000
# Computed couple 1688/5000
# Computed couple 1689/5000
# Computed couple 1690/5000
# Computed couple 1691/5000
# Computed couple 1692/5000
# Computed couple 1693/5000
# Computed couple 1694/5000
# Computed couple 1695/5000
# Computed couple 1696/5000
# Computed couple 1697/5000
# Computed couple 1698/5000
# Computed couple 1699/5000
# Computed couple 1700/5000
# Computed couple 1701/5000
# Computed couple 1702/5000
# Computed couple 1703/5000
# Computed couple 1704/5000
# Computed couple 1705/5000
# Computed couple 1706/5000
# Computed couple 1707/5000
# Computed couple 1708/5000
# Computed couple 1709/5000
# Computed couple 1710/5000
# Computed couple 1711/5000
# Computed couple 1712/5000
# Computed couple 1713/5000
# Computed couple 1714/5000
# Computed couple 1715/5000
# Computed couple 1716/5000
# Computed couple 1717/5000
# Computed couple 1718/5000
# Computed couple 1719/5000
# Computed couple 1720/5000
# Computed couple 1721/5000
# Computed couple 1722/5000
# Computed couple 1723/5000
# Computed couple 1724/5000
# Computed couple 1725/5000
# Computed couple 1726/5000
# Computed couple 1727/5000
# Computed couple 1728/5000
# Computed couple 1729/5000
# Computed couple 1730/5000
# Computed couple 1731/5000
# Computed couple 1732/5000
# Computed couple 1733/5000
# Computed couple 1734/5000
# Computed couple 1735/5000
# Computed couple 1736/5000
# Computed couple 1737/5000
# Computed couple 1738/5000
# Computed couple 1739/5000
# Computed couple 1740/5000
# Computed couple 1741/5000
# Computed couple 1742/5000
# Computed couple 1743/5000
# Computed couple 1744/5000
# Computed couple 1745/5000
# Computed couple 1746/5000
# Computed couple 1747/5000
# Computed couple 1748/5000
# Computed couple 1749/5000
# Computed couple 1750/5000
# Computed couple 1751/5000
# Computed couple 1752/5000
# Computed couple 1753/5000
# Computed couple 1754/5000
# Computed couple 1755/5000
# Computed couple 1756/5000
# Computed couple 1757/5000
# Computed couple 1758/5000
# Computed couple 1759/5000
# Computed couple 1760/5000
# Computed couple 1761/5000
# Computed couple 1762/5000
# Computed couple 1763/5000
# Computed couple 1764/5000
# Computed couple 1765/5000
# Computed couple 1766/5000
# Computed couple 1767/5000
# Computed couple 1768/5000
# Computed couple 1769/5000
# Computed couple 1770/5000
# Computed couple 1771/5000
# Computed couple 1772/5000
# Computed couple 1773/5000
# Computed couple 1774/5000
# Computed couple 1775/5000
# Computed couple 1776/5000
# Computed couple 1777/5000
# Computed couple 1778/5000
# Computed couple 1779/5000
# Computed couple 1780/5000
# Computed couple 1781/5000
# Computed couple 1782/5000
# Computed couple 1783/5000
# Computed couple 1784/5000
# Computed couple 1785/5000
# Computed couple 1786/5000
# Computed couple 1787/5000
# Computed couple 1788/5000
# Computed couple 1789/5000
# Computed couple 1790/5000
# Computed couple 1791/5000
# Computed couple 1792/5000
# Computed couple 1793/5000
# Computed couple 1794/5000
# Computed couple 1795/5000
# Computed couple 1796/5000
# Computed couple 1797/5000
# Computed couple 1798/5000
# Computed couple 1799/5000
# Computed couple 1800/5000
# Computed couple 1801/5000
# Computed couple 1802/5000
# Computed couple 1803/5000
# Computed couple 1804/5000
# Computed couple 1805/5000
# Computed couple 1806/5000
# Computed couple 1807/5000
# Computed couple 1808/5000
# Computed couple 1809/5000
# Computed couple 1810/5000
# Computed couple 1811/5000
# Computed couple 1812/5000
# Computed couple 1813/5000
# Computed couple 1814/5000
# Computed couple 1815/5000
# Computed couple 1816/5000
# Computed couple 1817/5000
# Computed couple 1818/5000
# Computed couple 1819/5000
# Computed couple 1820/5000
# Computed couple 1821/5000
# Computed couple 1822/5000
# Computed couple 1823/5000
# Computed couple 1824/5000
# Computed couple 1825/5000
# Computed couple 1826/5000
# Computed couple 1827/5000
# Computed couple 1828/5000
# Computed couple 1829/5000
# Computed couple 1830/5000
# Computed couple 1831/5000
# Computed couple 1832/5000
# Computed couple 1833/5000
# Computed couple 1834/5000
# Computed couple 1835/5000
# Computed couple 1836/5000
# Computed couple 1837/5000
# Computed couple 1838/5000
# Computed couple 1839/5000
# Computed couple 1840/5000
# Computed couple 1841/5000
# Computed couple 1842/5000
# Computed couple 1843/5000
# Computed couple 1844/5000
# Computed couple 1845/5000
# Computed couple 1846/5000
# Computed couple 1847/5000
# Computed couple 1848/5000
# Computed couple 1849/5000
# Computed couple 1850/5000
# Computed couple 1851/5000
# Computed couple 1852/5000
# Computed couple 1853/5000
# Computed couple 1854/5000
# Computed couple 1855/5000
# Computed couple 1856/5000
# Computed couple 1857/5000
# Computed couple 1858/5000
# Computed couple 1859/5000
# Computed couple 1860/5000
# Computed couple 1861/5000
# Computed couple 1862/5000
# Computed couple 1863/5000
# Computed couple 1864/5000
# Computed couple 1865/5000
# Computed couple 1866/5000
# Computed couple 1867/5000
# Computed couple 1868/5000
# Computed couple 1869/5000
# Computed couple 1870/5000
# Computed couple 1871/5000
# Computed couple 1872/5000
# Computed couple 1873/5000
# Computed couple 1874/5000
# Computed couple 1875/5000
# ...
# Computed Fourier 4528/5000
# Computed Fourier 4529/5000
# Computed Fourier 4530/5000
# Computed Fourier 4531/5000
# Computed Fourier 4532/5000
# Computed Fourier 4533/5000
# Computed Fourier 4534/5000
# Computed Fourier 4535/5000
# Computed Fourier 4536/5000
# Computed Fourier 4537/5000
# Computed Fourier 4538/5000
# Computed Fourier 4539/5000
# Computed Fourier 4540/5000
# Computed Fourier 4541/5000
# Computed Fourier 4542/5000
# Computed Fourier 4543/5000
# Computed Fourier 4544/5000
# Computed Fourier 4545/5000
# Computed Fourier 4546/5000
# Computed Fourier 4547/5000
# Computed Fourier 4548/5000
# Computed Fourier 4549/5000
# Computed Fourier 4550/5000
# Computed Fourier 4551/5000
# Computed Fourier 4552/5000
# Computed Fourier 4553/5000
# Computed Fourier 4554/5000
# Computed Fourier 4555/5000
# Computed Fourier 4556/5000
# Computed Fourier 4557/5000
# Computed Fourier 4558/5000
# Computed Fourier 4559/5000
# Computed Fourier 4560/5000
# Computed Fourier 4561/5000
# Computed Fourier 4562/5000
# Computed Fourier 4563/5000
# Computed Fourier 4564/5000
# Computed Fourier 4565/5000
# Computed Fourier 4566/5000
# Computed Fourier 4567/5000
# Computed Fourier 4568/5000
# Computed Fourier 4569/5000
# Computed Fourier 4570/5000
# Computed Fourier 4571/5000
# Computed Fourier 4572/5000
# Computed Fourier 4573/5000
# Computed Fourier 4574/5000
# Computed Fourier 4575/5000
# Computed Fourier 4576/5000
# Computed Fourier 4577/5000
# Computed Fourier 4578/5000
# Computed Fourier 4579/5000
# Computed Fourier 4580/5000
# Computed Fourier 4581/5000
# Computed Fourier 4582/5000
# Computed Fourier 4583/5000
# Computed Fourier 4584/5000
# Computed Fourier 4585/5000
# Computed Fourier 4586/5000
# Computed Fourier 4587/5000
# Computed Fourier 4588/5000
# Computed Fourier 4589/5000
# Computed Fourier 4590/5000
# Computed Fourier 4591/5000
# Computed Fourier 4592/5000
# Computed Fourier 4593/5000
# Computed Fourier 4594/5000
# Computed Fourier 4595/5000
# Computed Fourier 4596/5000
# Computed Fourier 4597/5000
# Computed Fourier 4598/5000
# Computed Fourier 4599/5000
# Computed Fourier 4600/5000
# Computed Fourier 4601/5000
# Computed Fourier 4602/5000
# Computed Fourier 4603/5000
# Computed Fourier 4604/5000
# Computed Fourier 4605/5000
# Computed Fourier 4606/5000
# Computed Fourier 4607/5000
# Computed Fourier 4608/5000
# Computed Fourier 4609/5000
# Computed Fourier 4610/5000
# Computed Fourier 4611/5000
# Computed Fourier 4612/5000
# Computed Fourier 4613/5000
# Computed Fourier 4614/5000
# Computed Fourier 4615/5000
# Computed Fourier 4616/5000
# Computed Fourier 4617/5000
# Computed Fourier 4618/5000
# Computed Fourier 4619/5000
# Computed Fourier 4620/5000
# Computed Fourier 4621/5000
# Computed Fourier 4622/5000
# Computed Fourier 4623/5000
# Computed Fourier 4624/5000
# Computed Fourier 4625/5000
# Computed Fourier 4626/5000
# Computed Fourier 4627/5000
# Computed Fourier 4628/5000
# Computed Fourier 4629/5000
# Computed Fourier 4630/5000
# Computed Fourier 4631/5000
# Computed Fourier 4632/5000
# Computed Fourier 4633/5000
# Computed Fourier 4634/5000
# Computed Fourier 4635/5000
# Computed Fourier 4636/5000
# Computed Fourier 4637/5000
# Computed Fourier 4638/5000
# Computed Fourier 4639/5000
# Computed Fourier 4640/5000
# Computed Fourier 4641/5000
# Computed Fourier 4642/5000
# Computed Fourier 4643/5000
# Computed Fourier 4644/5000
# Computed Fourier 4645/5000
# Computed Fourier 4646/5000
# Computed Fourier 4647/5000
# Computed Fourier 4648/5000
# Computed Fourier 4649/5000
# Computed Fourier 4650/5000
# Computed Fourier 4651/5000
# Computed Fourier 4652/5000
# Computed Fourier 4653/5000
# Computed Fourier 4654/5000
# Computed Fourier 4655/5000
# Computed Fourier 4656/5000
# Computed Fourier 4657/5000
# Computed Fourier 4658/5000
# Computed Fourier 4659/5000
# Computed Fourier 4660/5000
# Computed Fourier 4661/5000
# Computed Fourier 4662/5000
# Computed Fourier 4663/5000
# Computed Fourier 4664/5000
# Computed Fourier 4665/5000
# Computed Fourier 4666/5000
# Computed Fourier 4667/5000
# Computed Fourier 4668/5000
# Computed Fourier 4669/5000
# Computed Fourier 4670/5000
# Computed Fourier 4671/5000
# Computed Fourier 4672/5000
# Computed Fourier 4673/5000
# Computed Fourier 4674/5000
# Computed Fourier 4675/5000
# Computed Fourier 4676/5000
# Computed Fourier 4677/5000
# Computed Fourier 4678/5000
# Computed Fourier 4679/5000
# Computed Fourier 4680/5000
# Computed Fourier 4681/5000
# Computed Fourier 4682/5000
# Computed Fourier 4683/5000
# Computed Fourier 4684/5000
# Computed Fourier 4685/5000
# Computed Fourier 4686/5000
# Computed Fourier 4687/5000
# Computed Fourier 4688/5000
# Computed Fourier 4689/5000
# Computed Fourier 4690/5000
# Computed Fourier 4691/5000
# Computed Fourier 4692/5000
# Computed Fourier 4693/5000
# Computed Fourier 4694/5000
# Computed Fourier 4695/5000
# Computed Fourier 4696/5000
# Computed Fourier 4697/5000
# Computed Fourier 4698/5000
# Computed Fourier 4699/5000
# Computed Fourier 4700/5000
# Computed Fourier 4701/5000
# Computed Fourier 4702/5000
# Computed Fourier 4703/5000
# Computed Fourier 4704/5000
# Computed Fourier 4705/5000
# Computed Fourier 4706/5000
# Computed Fourier 4707/5000
# Computed Fourier 4708/5000
# Computed Fourier 4709/5000
# Computed Fourier 4710/5000
# Computed Fourier 4711/5000
# Computed Fourier 4712/5000
# Computed Fourier 4713/5000
# Computed Fourier 4714/5000
# Computed Fourier 4715/5000
# Computed Fourier 4716/5000
# Computed Fourier 4717/5000
# Computed Fourier 4718/5000
# Computed Fourier 4719/5000
# Computed Fourier 4720/5000
# Computed Fourier 4721/5000
# Computed Fourier 4722/5000
# Computed Fourier 4723/5000
# Computed Fourier 4724/5000
# Computed Fourier 4725/5000
# Computed Fourier 4726/5000
# Computed Fourier 4727/5000
# Computed Fourier 4728/5000
# Computed Fourier 4729/5000
# Computed Fourier 4730/5000
# Computed Fourier 4731/5000
# Computed Fourier 4732/5000
# Computed Fourier 4733/5000
# Computed Fourier 4734/5000
# Computed Fourier 4735/5000
# Computed Fourier 4736/5000
# Computed Fourier 4737/5000
# Computed Fourier 4738/5000
# Computed Fourier 4739/5000
# Computed Fourier 4740/5000
# Computed Fourier 4741/5000
# Computed Fourier 4742/5000
# Computed Fourier 4743/5000
# Computed Fourier 4744/5000
# Computed Fourier 4745/5000
# Computed Fourier 4746/5000
# Computed Fourier 4747/5000
# Computed Fourier 4748/5000
# Computed Fourier 4749/5000
# Computed Fourier 4750/5000
# Computed Fourier 4751/5000
# Computed Fourier 4752/5000
# Computed Fourier 4753/5000
# Computed Fourier 4754/5000
# Computed Fourier 4755/5000
# Computed Fourier 4756/5000
# Computed Fourier 4757/5000
# Computed Fourier 4758/5000
# Computed Fourier 4759/5000
# Computed Fourier 4760/5000
# Computed Fourier 4761/5000
# Computed Fourier 4762/5000
# Computed Fourier 4763/5000
# Computed Fourier 4764/5000
# Computed Fourier 4765/5000
# Computed Fourier 4766/5000
# Computed Fourier 4767/5000
# Computed Fourier 4768/5000
# Computed Fourier 4769/5000
# Computed Fourier 4770/5000
# Computed Fourier 4771/5000
# Computed Fourier 4772/5000
# Computed Fourier 4773/5000
# Computed Fourier 4774/5000
# Computed Fourier 4775/5000
# Computed Fourier 4776/5000
# Computed Fourier 4777/5000
# Computed Fourier 4778/5000
# Computed Fourier 4779/5000
# Computed Fourier 4780/5000
# Computed Fourier 4781/5000
# Computed Fourier 4782/5000
# Computed Fourier 4783/5000
# Computed Fourier 4784/5000
# Computed Fourier 4785/5000
# Computed Fourier 4786/5000
# Computed Fourier 4787/5000
# Computed Fourier 4788/5000
# Computed Fourier 4789/5000
# Computed Fourier 4790/5000
# Computed Fourier 4791/5000
# Computed Fourier 4792/5000
# Computed Fourier 4793/5000
# Computed Fourier 4794/5000
# Computed Fourier 4795/5000
# Computed Fourier 4796/5000
# Computed Fourier 4797/5000
# Computed Fourier 4798/5000
# Computed Fourier 4799/5000
# Computed Fourier 4800/5000
# Computed Fourier 4801/5000
# Computed Fourier 4802/5000
# Computed Fourier 4803/5000
# Computed Fourier 4804/5000
# Computed Fourier 4805/5000
# Computed Fourier 4806/5000
# Computed Fourier 4807/5000
# Computed Fourier 4808/5000
# Computed Fourier 4809/5000
# Computed Fourier 4810/5000
# Computed Fourier 4811/5000
# Computed Fourier 4812/5000
# Computed Fourier 4813/5000
# Computed Fourier 4814/5000
# Computed Fourier 4815/5000
# Computed Fourier 4816/5000
# Computed Fourier 4817/5000
# Computed Fourier 4818/5000
# Computed Fourier 4819/5000
# Computed Fourier 4820/5000
# Computed Fourier 4821/5000
# Computed Fourier 4822/5000
# Computed Fourier 4823/5000
# Computed Fourier 4824/5000
# Computed Fourier 4825/5000
# Computed Fourier 4826/5000
# Computed Fourier 4827/5000
# Computed Fourier 4828/5000
# Computed Fourier 4829/5000
# Computed Fourier 4830/5000
# Computed Fourier 4831/5000
# Computed Fourier 4832/5000
# Computed Fourier 4833/5000
# Computed Fourier 4834/5000
# Computed Fourier 4835/5000
# Computed Fourier 4836/5000
# Computed Fourier 4837/5000
# Computed Fourier 4838/5000
# Computed Fourier 4839/5000
# Computed Fourier 4840/5000
# Computed Fourier 4841/5000
# Computed Fourier 4842/5000
# Computed Fourier 4843/5000
# Computed Fourier 4844/5000
# Computed Fourier 4845/5000
# Computed Fourier 4846/5000
# Computed Fourier 4847/5000
# Computed Fourier 4848/5000
# Computed Fourier 4849/5000
# Computed Fourier 4850/5000
# Computed Fourier 4851/5000
# Computed Fourier 4852/5000
# Computed Fourier 4853/5000
# Computed Fourier 4854/5000
# Computed Fourier 4855/5000
# Computed Fourier 4856/5000
# Computed Fourier 4857/5000
# Computed Fourier 4858/5000
# Computed Fourier 4859/5000
# Computed Fourier 4860/5000
# Computed Fourier 4861/5000
# Computed Fourier 4862/5000
# Computed Fourier 4863/5000
# Computed Fourier 4864/5000
# Computed Fourier 4865/5000
# Computed Fourier 4866/5000
# Computed Fourier 4867/5000
# Computed Fourier 4868/5000
# Computed Fourier 4869/5000
# Computed Fourier 4870/5000
# Computed Fourier 4871/5000
# Computed Fourier 4872/5000
# Computed Fourier 4873/5000
# Computed Fourier 4874/5000
# Computed Fourier 4875/5000
# Computed Fourier 4876/5000
# Computed Fourier 4877/5000
# Computed Fourier 4878/5000
# Computed Fourier 4879/5000
# Computed Fourier 4880/5000
# Computed Fourier 4881/5000
# Computed Fourier 4882/5000
# Computed Fourier 4883/5000
# Computed Fourier 4884/5000
# Computed Fourier 4885/5000
# Computed Fourier 4886/5000
# Computed Fourier 4887/5000
# Computed Fourier 4888/5000
# Computed Fourier 4889/5000
# Computed Fourier 4890/5000
# Computed Fourier 4891/5000
# Computed Fourier 4892/5000
# Computed Fourier 4893/5000
# Computed Fourier 4894/5000
# Computed Fourier 4895/5000
# Computed Fourier 4896/5000
# Computed Fourier 4897/5000
# Computed Fourier 4898/5000
# Computed Fourier 4899/5000
# Computed Fourier 4900/5000
# Computed Fourier 4901/5000
# Computed Fourier 4902/5000
# Computed Fourier 4903/5000
# Computed Fourier 4904/5000
# Computed Fourier 4905/5000
# Computed Fourier 4906/5000
# Computed Fourier 4907/5000
# Computed Fourier 4908/5000
# Computed Fourier 4909/5000
# Computed Fourier 4910/5000
# Computed Fourier 4911/5000
# Computed Fourier 4912/5000
# Computed Fourier 4913/5000
# Computed Fourier 4914/5000
# Computed Fourier 4915/5000
# Computed Fourier 4916/5000
# Computed Fourier 4917/5000
# Computed Fourier 4918/5000
# Computed Fourier 4919/5000
# Computed Fourier 4920/5000
# Computed Fourier 4921/5000
# Computed Fourier 4922/5000
# Computed Fourier 4923/5000
# Computed Fourier 4924/5000
# Computed Fourier 4925/5000
# Computed Fourier 4926/5000
# Computed Fourier 4927/5000
# Computed Fourier 4928/5000
# Computed Fourier 4929/5000
# Computed Fourier 4930/5000
# Computed Fourier 4931/5000
# Computed Fourier 4932/5000
# Computed Fourier 4933/5000
# Computed Fourier 4934/5000
# Computed Fourier 4935/5000
# Computed Fourier 4936/5000
# Computed Fourier 4937/5000
# Computed Fourier 4938/5000
# Computed Fourier 4939/5000
# Computed Fourier 4940/5000
# Computed Fourier 4941/5000
# Computed Fourier 4942/5000
# Computed Fourier 4943/5000
# Computed Fourier 4944/5000
# Computed Fourier 4945/5000
# Computed Fourier 4946/5000
# Computed Fourier 4947/5000
# Computed Fourier 4948/5000
# Computed Fourier 4949/5000
# Computed Fourier 4950/5000
# Computed Fourier 4951/5000
# Computed Fourier 4952/5000
# Computed Fourier 4953/5000
# Computed Fourier 4954/5000
# Computed Fourier 4955/5000
# Computed Fourier 4956/5000
# Computed Fourier 4957/5000
# Computed Fourier 4958/5000
# Computed Fourier 4959/5000
# Computed Fourier 4960/5000
# Computed Fourier 4961/5000
# Computed Fourier 4962/5000
# Computed Fourier 4963/5000
# Computed Fourier 4964/5000
# Computed Fourier 4965/5000
# Computed Fourier 4966/5000
# Computed Fourier 4967/5000
# Computed Fourier 4968/5000
# Computed Fourier 4969/5000
# Computed Fourier 4970/5000
# Computed Fourier 4971/5000
# Computed Fourier 4972/5000
# Computed Fourier 4973/5000
# Computed Fourier 4974/5000
# Computed Fourier 4975/5000
# Computed Fourier 4976/5000
# Computed Fourier 4977/5000
# Computed Fourier 4978/5000
# Computed Fourier 4979/5000
# Computed Fourier 4980/5000
# Computed Fourier 4981/5000
# Computed Fourier 4982/5000
# Computed Fourier 4983/5000
# Computed Fourier 4984/5000
# Computed Fourier 4985/5000
# Computed Fourier 4986/5000
# Computed Fourier 4987/5000
# Computed Fourier 4988/5000
# Computed Fourier 4989/5000
# Computed Fourier 4990/5000
# Computed Fourier 4991/5000
# Computed Fourier 4992/5000
# Computed Fourier 4993/5000
# Computed Fourier 4994/5000
# Computed Fourier 4995/5000
# Computed Fourier 4996/5000
# Computed Fourier 4997/5000
# Computed Fourier 4998/5000
# Computed Fourier 4999/5000
# Computed Fourier 5000/5000
# Dataset saved: .\synth_dset_step_lambda=1064nm_Nmodes=269_degen=True_len=5000_mirr=64_exp_noise_1_of_1.hdf5
# Found 12 input variable weights below threshold 0.001 to delete.
# Successfully deleted low weight input variables.
# Computed TM row 1/132
# Computed TM row 2/132
# Computed TM row 3/132
# Computed TM row 4/132
# Computed TM row 5/132
# Computed TM row 6/132
# Computed TM row 7/132
# Computed TM row 8/132
# Computed TM row 9/132
# Computed TM row 10/132
# Computed TM row 11/132
# Computed TM row 12/132
# Computed TM row 13/132
# Computed TM row 14/132
# Computed TM row 15/132
# Computed TM row 16/132
# Computed TM row 17/132
# Computed TM row 18/132
# Computed TM row 19/132
# Computed TM row 20/132
# Computed TM row 21/132
# Computed TM row 22/132
# Computed TM row 23/132
# Computed TM row 24/132
# Computed TM row 25/132
# Computed TM row 26/132
# Computed TM row 27/132
# Computed TM row 28/132
# Computed TM row 29/132
# Computed TM row 30/132
# Computed TM row 31/132
# Computed TM row 32/132
# Computed TM row 33/132
# Computed TM row 34/132
# Computed TM row 35/132
# Computed TM row 36/132
# Computed TM row 37/132
# Computed TM row 38/132
# Computed TM row 39/132
# Computed TM row 40/132
# Computed TM row 41/132
# Computed TM row 42/132
# Computed TM row 43/132
# Computed TM row 44/132
# Computed TM row 45/132
# Computed TM row 46/132
# Computed TM row 47/132
# Computed TM row 48/132
# Computed TM row 49/132
# Computed TM row 50/132
# Computed TM row 51/132
# Computed TM row 52/132
# Computed TM row 53/132
# Computed TM row 54/132
# Computed TM row 55/132
# Computed TM row 56/132
# Computed TM row 57/132
# Computed TM row 58/132
# Computed TM row 59/132
# Computed TM row 60/132
# Computed TM row 61/132
# Computed TM row 62/132
# Computed TM row 63/132
# Computed TM row 64/132
# Computed TM row 65/132
# Computed TM row 66/132
# Computed TM row 67/132
# Computed TM row 68/132
# Computed TM row 69/132
# Computed TM row 70/132
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 14
#      11 dset._coupling_matrix = np.copy(common_coupling_matrix)
#      13 # Compute the near fields from the transfer matrix
# ---> 14 dset.compute_from_transfer_matrix(phases_dim=dataset_settings['phases_dim'])
#      16 # Compute the far fields from the near fields
#      17 dset.compute_fourier_transforms(**fourier_settings)
#
# File c:\users\saucourt\coding\mmf_lp_modes\mmfsim\datasets.py:322, in SimulatedSpeckleOutputDataset.compute_from_transfer_matrix(self, phases_dim, verbose, ref_phi)
#     320 phase_map = -np.pi + 2*np.pi*np.random.rand(*phases_dim)
#     321 dm.apply_phase_map(phase_map)
# --> 322 self._compute_transfer_matrix(dm, beam.grid)
#     323 tm = self.reshaped_transfer_matrix
#     324 self._normalized_energy_on_macropixels = dm.normalized_energies_on_macropixels
#
# File c:\users\saucourt\coding\mmf_lp_modes\mmfsim\datasets.py:356, in SimulatedSpeckleOutputDataset._compute_transfer_matrix(self, dm, grid)
#     354 self._input_modes_coeffs_matrix[i, :] = coupled_in.modes_coeffs
#     355 propagated_field = coupled_in.propagate(matrix=self._coupling_matrix)
# --> 356 self._transfer_matrix[i, :, :] = propagated_field
#     357 print(f"Computed TM row {i+1}/{dm._transfer_matrix_amplitudes.shape[0]}")
#
# KeyboardInterrupt:
