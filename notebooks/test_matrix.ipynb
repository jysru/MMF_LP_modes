# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

import mmfsim.matrix as mat

# %%
# M = mat.square_random_toeplitz(25, norm_intens=True, complex=True, decay_width=None)
M = mat.banana_random_toeplitz(100, norm_intens=True, complex=True, narrow_width=1, wide_width=50)

plt.imshow(np.abs(M),  cmap='gray')
plt.colorbar()
plt.show()

plt.imshow(np.angle(M), cmap='hsv')
plt.colorbar()
plt.show()
